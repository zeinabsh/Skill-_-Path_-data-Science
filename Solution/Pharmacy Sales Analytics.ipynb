# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

FactSales="C:/Users/banot/Desktop/data_analysispro/Pharma_Sales_Dataset/Pharmacy_Data_Challenge_Dataset.xlsx"

FactSales = pd.read_excel( file, sheet_name='FactSales')

FactSales

print(FactSales.head())
# Out:
#     SalesID   DateKey PharmacyID ProductID  UnitsSold  RevenueEUR  CostEUR  \
# 0  S0000001  20240101     PH0002    PR0099          5      128.08    87.55
# 1  S0000002  20240101     PH0004    PR0156          4       51.89    34.32
# 2  S0000003  20240101     PH0007    PR0004         20      317.73   199.53
# 3  S0000004  20240101     PH0009    PR0075          6       90.34    67.49
# 4  S0000005  20240101     PH0010    PR0154          2      160.21   124.99
#
#    MarginEUR PromoFlag
# 0      40.53        No
# 1      17.57        No
# 2     118.20        No
# 3      22.85        No
# 4      35.22       Yes

# %%
DimPharmacy=FactSales="C:/Users/banot/Desktop/data_analysispro/Pharma_Sales_Dataset/Pharmacy_Data_Challenge_Dataset.xlsx"
DimPharmacy = pd.read_excel( file, sheet_name='DimPharmacy')
