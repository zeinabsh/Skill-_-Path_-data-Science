# %%
# ==========================================
# PHARMACY SALES & PROFITABILITY ANALYSIS
# ==========================================

# ------------------------------------------
# IMPORT LIBRARIES
# ------------------------------------------

# Import:
# pandas
# numpy
# matplotlib.pyplot
# seaborn

# ------------------------------------------
# LOAD DATASET
# ------------------------------------------

# Read the Excel dataset using pandas

# Example:
# df = pd.read_excel("Pharmacy_Data_Challenge_Dataset.xlsx" , sheet_name='FactSales')

# ------------------------------------------
# DATA EXPLORATION
# ------------------------------------------

# Display:
# - First 5 rows
# - Dataset shape
# - Column names
# - Data types

# ------------------------------------------
# DATA CLEANING
# ------------------------------------------

# Tasks:
# 1. Check missing values
# 2. Remove duplicates
# 3. Convert date column to datetime
# 4. Clean text columns
# 5. Validate numeric columns
# 6. Detect outliers

# Suggested Columns to Check:
# - Revenue
# - Margin
# - Units_Sold
# - Country
# - Region
# - Pharmacy_Type
# - Category
# - Brand

# ------------------------------------------
# CREATE NEW DATE FEATURES
# ------------------------------------------

# Create:
# - Year column
# - Month column
# - Month Name column

# ------------------------------------------
# SALES ANALYSIS
# ------------------------------------------

# Questions:
# - How does revenue change over time?
# - Are there seasonal patterns?
# - Which months have highest/lowest sales?

# Visualization:
# Line Chart

# Compare:
# Date VS Revenue

# ------------------------------------------
# COUNTRY ANALYSIS
# ------------------------------------------

# Questions:
# - Which countries generate the highest revenue?
# - Which countries generate the highest margin?

# Visualization:
# Bar Chart

# Compare:
# Country VS Revenue
# Country VS Margin

# ------------------------------------------
# REGION ANALYSIS
# ------------------------------------------

# Questions:
# - Which regions perform best?
# - Compare regions by revenue and margin

# Visualization:
# Horizontal Bar Chart

# Compare:
# Region VS Revenue
# Region VS Margin

# ------------------------------------------
# PHARMACY PERFORMANCE ANALYSIS
# ------------------------------------------

# Questions:
# - Which pharmacies outperform others?
# - Which pharmacies underperform?

# Visualization:
# Bar Chart

# Compare:
# Pharmacy_Name VS Revenue

# ------------------------------------------
# PHARMACY TYPE ANALYSIS
# ------------------------------------------

# Questions:
# - Compare Urban, Suburban, and Rural pharmacies
# - Which type is most profitable?

# Visualization:
# Box Plot
# Bar Chart

# Compare:
# Pharmacy_Type VS Revenue
# Pharmacy_Type VS Margin

# ------------------------------------------
# PRODUCT CATEGORY ANALYSIS
# ------------------------------------------

# Questions:
# - Which categories generate highest revenue?
# - Which categories generate highest margin?

# Visualization:
# Bar Chart

# Compare:
# Category VS Revenue
# Category VS Margin

# ------------------------------------------
# BRAND ANALYSIS
# ------------------------------------------

# Questions:
# - Which brands perform best?
# - Which brands generate highest profit?

# Visualization:
# Bar Chart

# Compare:
# Brand VS Revenue
# Brand VS Margin

# ------------------------------------------
# PROMOTION ANALYSIS
# ------------------------------------------

# Questions:
# - Compare promoted and non-promoted sales
# - Do promotions improve revenue?
# - Do promotions reduce margin?

# Visualization:
# Grouped Bar Chart

# Compare:
# Promotion VS Revenue
# Promotion VS Margin
# Promotion VS Units_Sold

# ------------------------------------------
# CORRELATION ANALYSIS
# ------------------------------------------

# Questions:
# - Is there a relationship between:
#   Revenue
#   Margin
#   Units Sold

# Visualization:
# Heatmap

# Compare:
# Numeric Columns Correlation

# ------------------------------------------
# OUTLIER DETECTION
# ------------------------------------------

# Questions:
# - Are there unusual revenue values?
# - Are there extreme margins or unit sales?

# Visualization:
# Box Plot

# Compare:
# Revenue Distribution
# Margin Distribution

# ------------------------------------------
# OPTIONAL ADVANCED ANALYSIS
# ------------------------------------------

# Optional Tasks:
# - Top 10 products
# - Top 10 pharmacies
# - Revenue trend by country
# - Monthly sales forecasting
# - Interactive charts using Plotly

# ------------------------------------------
# FINAL BUSINESS INSIGHTS
# ------------------------------------------

# Students should summarize:
# - Key findings
# - Best performing countries
# - Best performing products
# - Business recommendations
# - Important trends discovered
